# %% [markdown]
# #### Usage:
# Import the modules.
# The method explore in the class ExploreData will generate a dashboard. First select the movie you want to look at in the list of available titles, then chose the emotions you want to see plotted:
# - sentiment analysis: overall positive and negative sentiment
# - emotion analysis: choose one or more of the 8 emotions
#
# >If you want to see the relative importance of emotions, click *See emotion importance for the whole script*. A slightly more detailed version is available by selecting *See emotion importance for the beginning, middle and end of the script*. Please note that these options are a little time consumming. Click on positive and negative options if you want to see them included in the bar graph.

# %% [markdown]
# ### importing modules

# %%
import os
import sys
import matplotlib.pyplot as plt
# %matplotlib inline
#widgets with notebook don't work as nicely
module_path = os.path.abspath(os.path.join('../code'))
if module_path not in sys.path:
    sys.path.append(module_path)
from load_plotline import LoadPlotLine, ExploreData

# %% [markdown]
# ### Data exploration

# %%
exploration = ExploreData()
select_widget, checkbox_list = exploration.explore()
